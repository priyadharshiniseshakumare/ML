# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
df = pd.read_csv("/content/insurance_data.csv")

# %%
df.head()
# Out:
#    age  bought_insurance
# 0   22                 0
# 1   25                 0
# 2   47                 1
# 3   52                 0
# 4   46                 1

# %%
plt.scatter(df.age, df.bought_insurance, marker='o', color = 'red')

# %%
df.shape
# Out:
# (27, 2)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(df[['age']],df.bought_insurance,test_size=0.2)

# %%
x_test
# Out:
#     age
# 4    46
# 12   27
# 22   40
# 10   18
# 26   23
# 17   58

# %%
x_train
# Out:
#     age
# 5    56
# 15   55
# 3    52
# 11   28
# 6    55
# 8    62
# 13   29
# 19   18
# 20   21
# 0    22
# 16   25
# 7    60
# 23   45
# 14   49
# 1    25
# 18   19
# 24   50
# 9    61
# 25   54
# 2    47
# 21   26

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
model.predict(x_test)
# Out:
# array([1, 0, 0, 0, 0, 1])

# %%
model.score(x_test,y_test)
# Out:
# 0.8333333333333334

# %%
model.predict_proba(x_test)
# Out:
# array([[0.33256718, 0.66743282],
#        [0.82794696, 0.17205304],
#        [0.50488298, 0.49511702],
#        [0.93372322, 0.06627678],
#        [0.88580263, 0.11419737],
#        [0.10632367, 0.89367633]])

# %%
model.predict(pd.DataFrame({'age': [25]}))
# Out:
# array([0])
